# %%
# Data Preprocessing for Trade Settlement Failure Prediction
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
os.chdir(r'D:\ShivaniG_AI_ML\capital-markets-trade-settlement-ml')

# %%
os.getcwd()
# Out:
# 'D:\\ShivaniG_AI_ML\\capital-markets-trade-settlement-ml'

# %%
# Load feature-engineered dataset
df = pd.read_csv(r'data\trade_settlement_dataset.csv')

# %%
df.head(5)
# Out:
#    trade_id security_isin security_type  trade_amount currency  \
# 0         1   US634895718          Bond    3576311.75      EUR
# 1         2   US299900595        Equity    2843515.34      USD
# 2         3   US962061404          Bond    4885423.38      JPY
# 3         4   US887846414    Derivative    1371385.12      USD
# 4         5   US227521863        Equity     800281.37      GBP
#
#      counterparty  counterparty_risk_score  historical_fail_rate  \
# 0            HSBC                    0.920                 0.140
# 1  Morgan Stanley                    0.488                 0.017
# 2            Citi                    0.064                 0.149
# 3        JPMorgan                    0.229                 0.029
# 4        JPMorgan                    0.579                 0.005
#
#    market_volatility_index  settlement_delay_days  settlement_failed
# 0                    37.12                      3                  1
# 1                    22.34                      1                  0
# 2                    33.80                      1                  0
# 3                    16.09                      3                  0
# 4                    24.81                      4                  0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   trade_id                 10000 non-null  int64
#  1   security_isin            10000 non-null  str
#  2   security_type            10000 non-null  str
#  3   trade_amount             10000 non-null  float64
#  4   currency                 10000 non-null  str
#  5   counterparty             10000 non-null  str
#  6   counterparty_risk_score  10000 non-null  float64
#  7   historical_fail_rate     10000 non-null  float64
#  8   market_volatility_index  10000 non-null  float64
#  9   settlement_delay_days    10000 non-null  int64
#  10  settlement_failed        10000 non-null  int64
# dtypes: float64(4), int64(3), str(4)
# memory usage: 1.1 MB

# %%
df.isnull().sum()
# Out:
# trade_id                   0
# security_isin              0
# security_type              0
# trade_amount               0
# currency                   0
# counterparty               0
# counterparty_risk_score    0
# historical_fail_rate       0
# market_volatility_index    0
# settlement_delay_days      0
# settlement_failed          0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 11)

# %%
# Filter invalid trades 
df = df[df["trade_amount"] > 0]

# %%
# Save cleaned data
df.to_csv(r"data\trade_settlement_clean.csv", index=False)

# %%
print(r"Data preprocessing completed. Clean file saved to ..data\trade_settlement_clean.csv")
# Out:
# Data preprocessing completed. Clean file saved to ..data\trade_settlement_clean.csv
